# %% [markdown]
# # Impact of Famous Athletes on Baby Names
#
# Big name athletes have a major impact on our culture, but do they influence the names of our babies? Let's find out.
#
# - Babe Ruth
# - Cassius Clay (Muhammad Ali)
# - Nolan Ryan
# - Greg Maddox
# - Michael Jordan
# - Tiger Woods
# - Mia Hamm
# - Serena Williams
# - Kobe Bryant
# - Lebron James

# %%
# Imports
import numpy as np
import pandas as pd
from bokeh.plotting import figure, show, output_notebook
from bokeh.palettes import brewer
colors = brewer['Spectral'][10]
output_notebook()

# Read the data
national_data = pd.read_csv("NationalNames.csv")
print("Baby names loaded!")
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="918cbb8b-f486-4996-b431-4ac61c58f809">Loading BokehJS ...</span>
#     </div>
# Baby names loaded!

# %%
# Create a dict with some of the world's top athletes with significant names. 
# Note: Active athletes have a retirement_year of 2014. 

athletes = [
    { 'name': 'Babe', 'full_name': 'Babe Ruth', 'rookie_year': 1914, 'retired_year': 1934, 'sex': 'M'},
    { 'name': 'Cassius', 'full_name': 'Cassius Clay', 'rookie_year': 1960, 'retired_year': 1979, 'sex': 'M'},
    { 'name': 'Nolan', 'full_name': 'Nolan Ryan', 'rookie_year': 1966, 'retired_year': 1993, 'sex': 'M'},
    { 'name': 'Maddux', 'full_name': 'Greg Maddux', 'rookie_year': 1986, 'retired_year': 2008, 'sex': 'M' },
    { 'name': 'Jordan', 'full_name': 'Michael Jordan', 'rookie_year': 1984, 'retired_year': 2003, 'sex': 'M' },
    { 'name': 'Mia', 'full_name': 'Mia Hamm', 'rookie_year': 1991, 'retired_year': 2004, 'sex': 'F' },
    { 'name': 'Tiger', 'full_name': 'Tiger Woods', 'rookie_year': 1996, 'retired_year': 2014, 'sex': 'M' },
    { 'name': 'Serena', 'full_name': 'Serena Williams', 'rookie_year': 1995, 'retired_year': 2014, 'sex': 'F' },
    { 'name': 'Kobe', 'full_name': 'Kobe Bryant', 'rookie_year': 1996, 'retired_year': 2014, 'sex': 'M' },
    { 'name': 'Lebron', 'full_name': 'Lebron James', 'rookie_year': 2003, 'retired_year': 2014, 'sex': 'M' }    
]          

# Utility method to print interesting stats for each athlete

def analyze_athlete(i, athlete): 
    # set variables for readability
    name, full_name, rookie_year, retired_year, sex  = athlete['name'], athlete['full_name'], athlete['rookie_year'], athlete['retired_year'], athlete['sex']
    
    # set DataFrame
    df = national_data[national_data['Name'] == name ]
    df = df[df['Gender'] == sex ]
    
    # calculate ranges for athletes career and prior generation
    career_years = range(rookie_year, retired_year)
    prior_generation_years = range(rookie_year-25, rookie_year)
    total_years = range(rookie_year-25, retired_year+25)
    
    # calculate interesting factoids
    rookie_name_count = df[df['Year'] == rookie_year]['Count'].sum()
    retired_name_count = df[df['Year'] == retired_year]['Count'].sum()
    career_name_count = df[df['Year'].isin(career_years)]['Count'].sum() 
    prior_name_count = df[df['Year'].isin(prior_generation_years)]['Count'].sum() 
    career_name_avg = round(df[df['Year'].isin(career_years)]['Count'].mean(), 2)
    prior_name_avg = round(df[df['Year'].isin(prior_generation_years)]['Count'].mean(), 2)
    influence_rate = round(100*(career_name_avg - prior_name_avg) / prior_name_avg, 2)
    influence_count = int(career_name_count - (prior_name_count*1.10)) # add 10% for approx 25y population growth
    
    
    # plot the trends
    p = figure(title=(full_name+' Inspired Trends'), x_axis_label='Year', y_axis_label='Count')
    
    df = df[df['Year'].isin(total_years)]
    x = df['Year'].tolist()
    y = df['Count'].tolist()  
    
    p.line(x, y, legend=name, line_width=2, line_color=colors[i], line_cap='round')
    p.quad(top=[(max(y))], bottom=[0], left=[rookie_year],
       right=[retired_year], color="#B3DE69", alpha=0.3, legend="Active Career")
    show(p)
    
    
    # print the some factoids
    print("Here's how {0} influenced for the name '{1}':".format(full_name, name))
    print("{0} babies named {1} were born in {2}, {3}'s rookie year.".format(rookie_name_count, name, rookie_year, full_name))
    print("{0} babies named {1} were born in {2}, {3}'s last active year.".format(retired_name_count, name, retired_year, full_name))
    print("On average, {0} babies named {1} were born per year while athlete's career was active.".format(career_name_avg, name))
    print("Comparatively, babies named {1} averaged {0} in the preceeding generation (25 years).".format(prior_name_avg, name))
    print("The frequency of babies named {0} changed by {1}% after the athlete's rookie debut.".format(name, influence_rate))
    print("{0} probablly inspired the names of {1} babies.".format(full_name, influence_count))

    
analyze_athlete(3, athletes[9])
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="4b926f1e-adea-43e5-a7c7-7e9236e274fb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4b926f1e-adea-43e5-a7c7-7e9236e274fb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4b926f1e-adea-43e5-a7c7-7e9236e274fb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a015ea20-c1fb-42c5-bd93-785717991b1a":{"roots":{"references":[{"attributes":{"legends":[["Lebron",[{"id":"f0d215ad-af27-4364-b4f9-03d5f8f68d73","type":"GlyphRenderer"}]],["Active Career",[{"id":"e1169264-ec72-4e73-b7b4-bb079d7ca295","type":"GlyphRenderer"}]]],"plot":{"id":"c5c30333-4d36-4b93-92f4-9cdff4636b70","subtype":"Figure","type":"Plot"}},"id":"45372265-3391-49ed-8acc-ec3fd8bcd026","type":"Legend"},{"attributes":{"plot":{"id":"c5c30333-4d36-4b93-92f4-9cdff4636b70","subtype":"Figure","type":"Plot"},"ticker":{"id":"6296f915-66bf-4c82-854e-79c670c56952","type":"BasicTicker"}},"id":"79341cb3-e5f1-4d6c-8ae3-7ff161f4e9c0","type":"Grid"},{"attributes":{"plot":{"id":"c5c30333-4d36-4b93-92f4-9cdff4636b70","subtype":"Figure","type":"Plot"}},"id":"f8b98dc1-cf8e-4924-a578-1d144c542aa3","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"5092cdbd-8e64-4f76-9e27-c4e1980fed10","type":"ColumnDataSource"},"glyph":{"id":"3d5865b9-3cfc-47e6-8639-f712fe7d0fda","type":"Quad"},"hover_glyph":null,"nonselection_glyph":{"id":"f86904ef-2b1d-426a-a37a-0a22865d131a","type":"Quad"},"selection_glyph":null},"id":"e1169264-ec72-4e73-b7b4-bb079d7ca295","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"54858975-4233-4ef3-ba4f-99d26a1191c4","type":"BoxAnnotation"},{"attributes":{"dimension":1,"plot":{"id":"c5c30333-4d36-4b93-92f4-9cdff4636b70","subtype":"Figure","type":"Plot"},"ticker":{"id":"88f022db-0077-4249-be4b-c6cbbacb44dd","type":"BasicTicker"}},"id":"709bf601-e9cb-4232-90a5-10cbd8a869c4","type":"Grid"},{"attributes":{"plot":{"id":"c5c30333-4d36-4b93-92f4-9cdff4636b70","subtype":"Figure","type":"Plot"}},"id":"eb853132-0cc3-424d-a8ca-a0f82faf24b7","type":"SaveTool"},{"attributes":{"plot":null,"text":"Lebron James Inspired Trends"},"id":"d3572f6a-c13a-4a1d-9473-0838e5271686","type":"Title"},{"attributes":{"overlay":{"id":"54858975-4233-4ef3-ba4f-99d26a1191c4","type":"BoxAnnotation"},"plot":{"id":"c5c30333-4d36-4b93-92f4-9cdff4636b70","subtype":"Figure","type":"Plot"}},"id":"c858eaf5-c673-462a-8caf-7f79b7cdaac7","type":"BoxZoomTool"},{"attributes":{"axis_label":"Count","formatter":{"id":"441d6e1f-a887-47db-8efb-ceb06370d76f","type":"BasicTickFormatter"},"plot":{"id":"c5c30333-4d36-4b93-92f4-9cdff4636b70","subtype":"Figure","type":"Plot"},"ticker":{"id":"88f022db-0077-4249-be4b-c6cbbacb44dd","type":"BasicTicker"}},"id":"d08b1f4f-0156-4f8a-9b39-871ba4a4bff9","type":"LinearAxis"},{"attributes":{},"id":"441d6e1f-a887-47db-8efb-ceb06370d76f","type":"BasicTickFormatter"},{"attributes":{"bottom":{"field":"bottom"},"fill_alpha":{"value":0.3},"fill_color":{"value":"#B3DE69"},"left":{"field":"left"},"line_alpha":{"value":0.3},"line_color":{"value":"#B3DE69"},"right":{"field":"right"},"top":{"field":"top"}},"id":"3d5865b9-3cfc-47e6-8639-f712fe7d0fda","type":"Quad"},{"attributes":{"line_cap":"round","line_color":{"value":"#abdda4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"1a798889-ce2f-4474-a507-1bd65d269632","type":"Line"},{"attributes":{},"id":"6296f915-66bf-4c82-854e-79c670c56952","type":"BasicTicker"},{"attributes":{"data_source":{"id":"99210835-262b-4e56-b0c1-efa590115f82","type":"ColumnDataSource"},"glyph":{"id":"1a798889-ce2f-4474-a507-1bd65d269632","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"5e81f587-ecad-4069-a122-3148b609b219","type":"Line"},"selection_glyph":null},"id":"f0d215ad-af27-4364-b4f9-03d5f8f68d73","type":"GlyphRenderer"},{"attributes":{"axis_label":"Year","formatter":{"id":"5259566b-c2b0-4a77-806e-4e5afbe7e1b6","type":"BasicTickFormatter"},"plot":{"id":"c5c30333-4d36-4b93-92f4-9cdff4636b70","subtype":"Figure","type":"Plot"},"ticker":{"id":"6296f915-66bf-4c82-854e-79c6 ...
# Here's how Lebron James influenced for the name 'Lebron':
# 42 babies named Lebron were born in 2003, Lebron James's rookie year.
# 39 babies named Lebron were born in 2014, Lebron James's last active year.
# On average, 80.45 babies named Lebron were born per year while athlete's career was active.
# Comparatively, babies named Lebron averaged 6.36 in the preceeding generation (25 years).
# The frequency of babies named Lebron changed by 1164.94% after the athlete's rookie debut.
# Lebron James probablly inspired the names of 787 babies.

# %% [markdown]
# ## Visualizing the Impact

# %%
for i, athlete in enumerate(athletes): 
    analyze_athlete(i, athlete)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="667146b2-3f71-475d-9ce2-a9da09eca895"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("667146b2-3f71-475d-9ce2-a9da09eca895");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '667146b2-3f71-475d-9ce2-a9da09eca895' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"15dcda64-d5d8-492d-926d-b65d94e27c16":{"roots":{"references":[{"attributes":{"line_cap":"round","line_color":{"value":"#5e4fa2"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"68d57907-13ca-4a1f-b99f-16101e6cb8e4","type":"Line"},{"attributes":{},"id":"956c99ca-868a-4e4f-bc78-aa56bdffb25e","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"f8adbfd6-9079-499b-9f69-7e96326bd485","type":"BoxAnnotation"},{"attributes":{"bottom":{"field":"bottom"},"fill_alpha":{"value":0.3},"fill_color":{"value":"#B3DE69"},"left":{"field":"left"},"line_alpha":{"value":0.3},"line_color":{"value":"#B3DE69"},"right":{"field":"right"},"top":{"field":"top"}},"id":"a62478df-2cdf-4d3c-9ae9-ba4f7106c2c2","type":"Quad"},{"attributes":{},"id":"98446f42-9182-4ddf-8edb-bbcc7412c545","type":"BasicTickFormatter"},{"attributes":{},"id":"92d2c171-ce5a-4038-b0c1-5afed11e8a6d","type":"ToolEvents"},{"attributes":{"below":[{"id":"0507a805-9c9d-4685-84a1-ff30d92d1005","type":"LinearAxis"}],"left":[{"id":"11d85910-6cb9
# Here's how Babe Ruth influenced for the name Babe:
# 6 babies named Babe were born in 1914, Babe Ruth's rookie year.
# 7 babies named Babe were born in 1934, Babe Ruth's last active year.
# On average, 10.16 babies named Babe were born while athlete's career was active.
# Comparatively, babies named Babe averaged 6.5 in the preceeding generation (25 years).
# The frequency of babies named Babe changed by 56.31% after the athlete's rookie debut.
# Babe Ruth probablly inspired the names of 121 babies.
#     <div class="bk-root">
#         <div class="plotdiv" id="3be69f7b-9d54-4a96-b990-cd1bcbc3207f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3be69f7b-9d54-4a96-b990-cd1bcbc3207f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3be69f7b-9d54-4a96-b990-cd1bcbc3207f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"3c379001-c986-41d8-bb3d-9f7fc0c3fc39":{"roots":{"references":[{"attributes":{"line_cap":"round","line_color":{"value":"#3288bd"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"7403b252-3356-4d8a-9e26-0891e61c3069","type":"Line"},{"attributes":{},"id":"24134367-fcc1-46f8-aee9-4a6ed0a59081","type":"BasicTickFormatter"},{"attributes":{"line_alpha":{"value":0.1},"line_cap":"round","line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"fae4a56a-c514-49df-8595-abe3fb3e1ad7","type":"Line"},{"attributes":{"axis_label":"Count","formatter":{"id":"24134367-fcc1-46f8-aee9-4a6ed0a59081","type":"BasicTickFormatter"},"plot":{"id":"9421d98d-cedc-468b-9240-96df2d19bcdd","subtype":"Figure","type":"Plot"},"ticker":{"id":"2ce1478f-2a0e-40ad-b7e9-034bc394a4e5","type":"BasicTicker"}},"id":"181b6ae6-7322-42ad-8ed7-400111cee9e1","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"9421d98d-cedc-468b-9240-96df2d19bcdd","subtype":"Figure","type":"Plot"},"ticker":{"id":"2ce1478f-2a0e-40ad-b7e9-034bc394a4e5","type":"BasicTicker"}},"id":"0c982f75-34ae-4f36-a228-996b56435f94","type":"Grid"},{"attributes":{"data_source":{"id":"47fcaf41-0814-45fe-9463-bff42425e2e3","type":"ColumnDataSource"},"glyph":{"id":"7403b252-3356-4d8a-9e26-0891e61c3069","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"fae4a56a-c514-49df-8595-abe3fb3e1ad7","type":"Line"},"selection_glyph":null},"id":"f79dddfc-a700-4564-a380-42b39939fb9b","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"a33a9b7d-d938-45b0-b330-54630f6690e2","type":"DataRange1d"},{"attributes":{"plot":{"id":"9421d98d-cedc-468b-9240-96df2d19bcdd","subtype":"Figure","type":"Plot"}},"id":"5f15470d-df23-4e20-bf9b-fb517eb2b3ea","type":"PanTool"},{"attributes":{"below":[{"id":"b39e2066-3bfc-4637-9bb0-ec71fa09ed0b","type":"LinearAxis"}],"left":[{"id":"181b6ae6-7322-42ad-8ed7-400111cee9e1","type":"LinearAxis"}],"renderers":[{"id":"b39e2066-3bfc-4637-9bb0-ec71fa09ed0b","type":"LinearAxis"},{"id":"eba13fdf-08d5-46f1-9923-21ba310616d5","type":"Grid"},{"id":"181b6ae6-7322-42ad-8ed7-400111cee9e1","type":"LinearAxis"},{"id":"0c982f75-34ae-4f36-a228-996b56435f94","type":"Grid"},{"id":"0b53982f-7d63-4852-8cbe-323d2f8c087f","type":"BoxAnnotation"},{"id":"766c4dd1-a59b-493c-8ea5-41cca30f9ded","type":"Legend"},{"id":"f79dddfc-a700-4564-a380-42b39939fb9b","type":"GlyphRenderer"},{"id":"ad8f6cb2-f9c4-4f4b-8aac-bf2d04c80691","type":"GlyphRenderer"}],"title":{"id":"7a11bb84-eb32-4dbc-850d-bc69a5c76345","type":"Title"},"tool_events":{"id":"2ede3858-1e4f-400e-9bb8-52bf6e514ef3","type":"ToolEvents"},"toolbar":{"id":"d73c579b-1449-4496-ba43-6408446dd460","type":"Toolbar"},"x_range":{"id":"efb2d952-176e-4e37-9bb9-fba1e5b5c7a2","type":"DataRange1d"},"y_range":{"id":"a33a9b7d-d938-45b0-b330-54630f6690e2","type":"DataRange1d"}},"id":"9421d98d-cedc-468b-9240-96df2d19bcdd","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"9421d98d-cedc-468b-9240-96df2d19bcdd","subtype":"Figure","type":"Plot"}},"id":"ffb549e5-133d-45de-b301-6db4f7ccafd4","type":"SaveTool"},{"attributes":{"plot":{"id":"9421d98d-cedc-468b-9240-96df2d19bcdd","subtype":"Figure","type":"Plot"},"ticker":{"id":"c668bdee-b56e-4597-aa19-e77d241f02fc","type":"BasicTicker"}},"id":"eba13fdf-08d5-46f1-9923-21ba310616d5","type":"Grid"},{"attributes":{"callback":null},"id":"efb2d952-176e-4e37-9bb9-fba1e5b5c7a2","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"5f15470d-df23-4e20-bf9b-fb517eb2b3ea","type":"PanTool"},{"id":"8e5cec06-06cc-4f9e-8331-75e47300cc27","type":"WheelZoomTool"},{"id":"2c94a4c1-2344-45c7-883e-8bbd64f19126","type":"BoxZoomTool"},{"id":"ffb549e5-133d-45de-b301-6db4f7ccafd4","type":"SaveTool"},{"id":"18b4c95c-d1a7-4b79-b5b5-9c72dead69b3","type":"ResetTool"},{"id":"2bfe8fd1-56a5-40bc-b5e1-44f12078f769","type":"HelpTool"}]},"id":"d73c579b-1449-4496-ba43-6408446dd460","type":"T ...
# Here's how Cassius Clay influenced for the name Cassius:
# 8 babies named Cassius were born in 1960, Cassius Clay's rookie year.
# 16 babies named Cassius were born in 1979, Cassius Clay's last active year.
# On average, 25.32 babies named Cassius were born while athlete's career was active.
# Comparatively, babies named Cassius averaged 7.33 in the preceeding generation (25 years).
# The frequency of babies named Cassius changed by 245.43% after the athlete's rookie debut.
# Cassius Clay probablly inspired the names of 360 babies.
#     <div class="bk-root">
#         <div class="plotdiv" id="ede2e502-9656-46e2-8840-865cf4d00629"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ede2e502-9656-46e2-8840-865cf4d00629");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ede2e502-9656-46e2-8840-865cf4d00629' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"546fdf58-edae-4372-aead-45a6f2da6b91":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"af16ab36-f5a8-40b0-89f4-46a896f80371","subtype":"Figure","type":"Plot"},"ticker":{"id":"17df8d2e-fb1c-4b2c-bcd5-11d50d0e43d4","type":"BasicTicker"}},"id":"64061065-0a4e-48eb-80ae-aaaf7cf4aef9","type":"Grid"},{"attributes":{},"id":"17df8d2e-fb1c-4b2c-bcd5-11d50d0e43d4","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"fb8d49da-7e7c-4c1b-919f-b97aad76703f","type":"PanTool"},{"id":"e5581079-e260-4ecb-b014-2470a4086133","type":"WheelZoomTool"},{"id":"ea230925-c921-4ed7-ad0d-3daf73616524","type":"BoxZoomTool"},{"id":"736feebb-9532-4303-be71-88ce6b9533d2","type":"SaveTool"},{"id":"64efab7f-400f-4918-a59e-a5a146c47654","type":"ResetTool"},{"id":"57fe3866-572a-4b31-b310-610eb0e67dcc","type":"HelpTool"}]},"id":"a4c32eba-c5fb-43cd-826a-b59f447f829f","type":"Toolbar"},{"attributes":{"plot":{"id":"af16ab36-f5a8-40b0-89f4-46a896f80371","subtype":"Figure","type":"Plot"}},"id":"64efab7f-400f-4918-a59e-a5a146c47654","type":"ResetTool"},{"attributes":{"plot":{"id":"af16ab36-f5a8-40b0-89f4-46a896f80371","subtype":"Figure","type":"Plot"}},"id":"736feebb-9532-4303-be71-88ce6b9533d2","type":"SaveTool"},{"attributes":{"line_cap":"round","line_color":{"value":"#66c2a5"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"61c10ad9-da49-49e9-99dd-ae6a3f0b648e","type":"Line"},{"attributes":{"plot":null,"text":"Nolan Ryan Inspired Trends: Nolan"},"id":"cba5751f-e503-4742-a956-a456bec70c58","type":"Title"},{"attributes":{},"id":"085693b0-8e5a-46f9-b921-5fc44b1257f6","type":"ToolEvents"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1941,1942,1943,1944,1945,1946,1947,1948,1949,1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014],"y":[175,192,206,206,174,193,198,218,219,216,188,212,189,206,198,198,184,181,186,165,165,142,156,164,112,160,128,147,157,180,200,146,175,167,201,203,218,258,262,329,395,422,448,519,478,479,481,508,617,845,1055,1163,1144,1112,1066,1106,1311,1364,1623,2027,2092,2232,2216,2488,2717,2838,3170,3149,3434,3684,4163,4423,4736,5181]}},"id":"31649f72-7ac4-453d-aaae-517c580120f7","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"46d964b9-e93a-4a1f-93da-f6e217a02242","type":"ColumnDataSource"},"glyph":{"id":"50f3353f-51ac-420a-97dc-dbead23d8216","type":"Quad"},"hover_glyph":null,"nonselection_glyph":{"id":"ad6d6652-e9b8-483f-8e5b-f80623cd408a","type":"Quad"},"selection_glyph":null},"id":"f523a223-9e44-4afd-94b2-dfd713643c1e","type":"GlyphRenderer"},{"attributes":{"axis_label":"Count","formatter":{"id":"d0fa84d8-cece-49d0-88b2-0609c2c06da0","type":"BasicTickFormatter"},"plot":{"id":"af16ab36-f5a8-40b0-89f4-46a896f80371","subtype":"Figure","type":"Plot"},"ticker":{"id":"17df8d2e-fb1c-4b2c-bcd5-11d50d0e43d4","type":"BasicTicker"}},"id":"e1f3a3f1-7c15-47e7-901b-b9612ce887db","type":"LinearAxis"},{"attributes":{"overlay":{"id":"5ed0cca1-b0a2-4da5-a446-cf24f101a490","type":"BoxAnnotation"},"plot":{"id":"af16ab36-f5a8-40b0-89f4-46a896f80371","subtype":"Figure","type":"Plot"}},"id":"ea230925-c921-4ed7-ad0d-3daf73616524","type":"BoxZoomTool"},{"attributes":{"line_alpha":{"value":0.1},"line_cap":"round","line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"820a1e78-b439-4f4b-a156-bca35d435132","type":"Line"},{"attributes":{"bottom":{"field":"bottom"},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"ad6d6652-e9b8-483f-8e5b-f80623cd408a","type" ...
# Here's how Nolan Ryan influenced for the name Nolan:
# 160 babies named Nolan were born in 1966, Nolan Ryan's rookie year.
# 1144 babies named Nolan were born in 1993, Nolan Ryan's last active year.
# On average, 383.0 babies named Nolan were born while athlete's career was active.
# Comparatively, babies named Nolan averaged 185.72 in the preceeding generation (25 years).
# The frequency of babies named Nolan changed by 106.22% after the athlete's rookie debut.
# Nolan Ryan probablly inspired the names of 5233 babies.
#     <div class="bk-root">
#         <div class="plotdiv" id="06aa41a5-6001-4ade-bfd9-1d7d55fc8947"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("
"80a3e894-b538-428d-87ba-8b0285b349d2","type":"Grid"},{"id":"9e9a46cc-ffbf-4829-be91-b33696ccca0b","type":"BoxAnnotation"},{"id":"2f97401e-bd43-412a-87e3-dd45d2b074e0","type":"Legend"},{"id":"f251a826-41cd-4ec0-868e-ce7d452afdae","type":"GlyphRenderer"},{"id":"94d03391-1d5d-461d-ac2b-df33c7301acf","type":"GlyphRenderer"}],"title":{"id":"84922840-7005-4b85-b956-8247fcf3a279","type":"Title"},"tool_events":{"id":"58ddca99-ec07-461a-8993-5b6af656cb77","type":"ToolEvents"},"toolbar":{"id":"668bcd6d-3d63-478c-aaec-61dc33dd220e","type":"Toolbar"},"x_range":{"id":"448fdd4f-5f8f-4bf4-ab3e-88c8c8962fca","type":"DataRange1d"},"y_range":{"id":"1a8819b1-156e-4d46-93eb-27c72a3ab407","type":"DataRange1d"}},"id":"c964b0d2-3438-4d20-a1c6-42cff29afb97","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"58ddca99-ec07-461a-8993-5b6af656cb77","type":"ToolEvents"},{"attributes":{"line_cap":"round","line_color":{"value":"#abdda4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"639a0fb3-434f-4bce-8018-c6af18372764","type":"Line"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"l ...
# Here's how Greg Maddux influenced for the name Maddux:
# 0 babies named Maddux were born in 1986, Greg Maddux's rookie year.
# 181 babies named Maddux were born in 2008, Greg Maddux's last active year.
# On average, 58.58 babies named Maddux were born while athlete's career was active.
# Comparatively, babies named Maddux averaged nan in the preceeding generation (25 years).
# The frequency of babies named Maddux changed by nan% after the athlete's rookie debut.
# Greg Maddux probablly inspired the names of 703 babies.
#     <div class="bk-root">
#         <div class="plotdiv" id="adb81747-7753-420b-b0b1-63c272e1b92e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("adb81747-7753-420b-b0b1-63c272e1b92e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'adb81747-7753-420b-b0b1-63c272e1b92e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"61ba326f-6bfd-421b-afc9-5680d087b040":{"roots":{"references":[{"attributes":{"legends":[["Jordan",[{"id":"1f2355ba-b79c-43ed-a81b-d8b57c91e81d","type":"GlyphRenderer"}]],["Active Career",[{"id":"f63471df-f023-4570-a61c-cdb918e2ba3b","type":"GlyphRenderer"}]]],"plot":{"id":"1fb9de89-f9c1-4d8c-a659-fb0a04bbdad7","subtype":"Figure","type":"Plot"}},"id":"140681e3-0cf6-4e15-b62b-a1becfe84704","type":"Legend"},{"attributes":{"line_alpha":{"value":0.1},"line_cap":"round","line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"c41d923d-e4d7-4450-936b-082121bd7d0a","type":"Line"},{"attributes":{"callback":null},"id":"4aefb316-e9ab-47ab-a9fa-2c51135cb60c","type":"DataRange1d"},{"attributes":{"plot":null,"text":"Michael Jordan Inspired Trends: Jordan"},"id":"1749d998-4041-4698-a3f9-16ee15e7dce8","type":"Title"},{"attributes":{"axis_label":"Year","formatter":{"id":"a3b5f776-c7d5-4ba2-b5d1-d9534d6a68fd","type":"BasicTickFormatter"},"plot":{"id":"1fb9de89-f9c1-4d8c-a659-fb0a04bbdad7","subtype":"Figure","type":"Plot"},"ticker":{"id":"b683b105-fa6f-442a-bb7d-ad5ecfad1d22","type":"BasicTicker"}},"id":"9cb96a47-7718-4b12-9aff-6ffabfd0b22f","type":"LinearAxis"},{"attributes":{"overlay":{"id":"3e8cc2af-2c0c-410c-9e53-3f3c9bccd20f","type":"BoxAnnotation"},"plot":{"id":"1fb9de89-f9c1-4d8c-a659-fb0a04bbdad7","subtype":"Figure","type":"Plot"}},"id":"0a4bfccd-a3e9-46c3-8c35-bb6a17ff9329","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"1fb9de89-f9c1-4d8c-a659-fb0a04bbdad7","subtype":"Figure","type":"Plot"}},"id":"74c20013-d312-4fa4-ac6b-d546be611fdf","type":"HelpTool"},{"attributes":{"below":[{"id":"9cb96a47-7718-4b12-9aff-6ffabfd0b22f","type":"LinearAxis"}],"left":[{"id":"1e409eee-cbf6-4476-a235-1217fe36f8c9","type":"LinearAxis"}],"renderers":[{"id":"9cb96a47-7718-4b12-9aff-6ffabfd0b22f","type":"LinearAxis"},{"id":"7ce57537-4b11-4d01-a254-aa35e0bfdcee","type":"Grid"},{"id":"1e409eee-cbf6-4476-a235-1217fe36f8c9","type":"LinearAxis"},{"id":"c9fc2034-81dc-45b7-b5f1-75df605c3875","type":"Grid"},{"id":"3e8cc2af-2c0c-410c-9e53-3f3c9bccd20f","type":"BoxAnnotation"},{"id":"140681e3-0cf6-4e15-b62b-a1becfe84704","type":"Legend"},{"id":"1f2355ba-b79c-43ed-a81b-d8b57c91e81d","type":"GlyphRenderer"},{"id":"f63471df-f023-4570-a61c-cdb918e2ba3b","type":"GlyphRenderer"}],"title":{"id":"1749d998-4041-4698-a3f9-16ee15e7dce8","type":"Title"},"tool_events":{"id":"59ddfa41-fd28-4c5a-afba-7292a355f49b","type":"ToolEvents"},"toolbar":{"id":"72fcfd74-98a0-46b9-b44f-008aba099ebc","type":"Toolbar"},"x_range":{"id":"4aefb316-e9ab-47ab-a9fa-2c51135cb60c","type":"DataRange1d"},"y_range":{"id":"de8165ab-44a5-4b23-ab0e-a1f7ec8df5c9","type":"DataRange1d"}},"id":"1fb9de89-f9c1-4d8c-a659-fb0a04bbdad7","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"1fb9de89-f9c1-4d8c-a659-fb0a04bbdad7","subtype":"Figure","type":"Plot"}},"id":"526dfd79-7ab2-4a7e-a035-bc6f974dad6d","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"1fb9de89-f9c1-4d8c-a659-fb0a04bbdad7","subtype":"Figure","type":"Plot"}},"id":"4de561ef-c73a-4a53-9c2c-67a43982b892","type":"PanTool"},{"attributes":{},"id":"a3b5f776-c7d5-4ba2-b5d1-d9534d6a68fd","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"de8165ab-44a5-4b23-ab0e-a1f7ec8df5c9","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014],"y":[159,137,187,182,154,165,179,212,222,189,223,280,290,259,305,369,398,518,649,979,1406,1616,2924,3535,4012,4538,5456,7296,8407,8481,10869,16128,16013,14029,14753,14161,13567,13852,14759,14409,13048,12164,10812,11145,10325,9548,9389,9917,10034,9073,8640,8223,8041,7782,7167,6810]}},"id":"ed5e6d13-52df-45e4-9717-b54cfb787b ...
# Here's how Michael Jordan influenced for the name Jordan:
# 4538 babies named Jordan were born in 1984, Michael Jordan's rookie year.
# 10325 babies named Jordan were born in 2003, Michael Jordan's last active year.
# On average, 11783.53 babies named Jordan were born while athlete's career was active.
# Comparatively, babies named Jordan averaged 781.96 in the preceeding generation (25 years).
# The frequency of babies named Jordan changed by 1406.92% after the athlete's rookie debut.
# Michael Jordan probablly inspired the names of 202383 babies.
#     <div class="bk-root">
#         <div class="plotdiv" id="f1ffb48a-7775-4cb1-a504-afd622075453"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f1ffb48a-7775-4cb1-a504-afd622075453");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f1ffb48a-7775-4cb1-a504-afd622075453' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"e05eb682-7c96-408b-8c99-0e8e42628807":{"roots":{"references":[{"attributes":{"overlay":{"id":"1bd9952c-0339-4639-bba1-da297bae58f0","type":"BoxAnnotation"},"plot":{"id":"23ba4b25-1cba-4100-8b68-3f73c87bf029","subtype":"Figure","type":"Plot"}},"id":"b61c8d85-4a86-415d-9ae6-5ef294dd354b","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"23ba4b25-1cba-4100-8b68-3f73c87bf029","subtype":"Figure","type":"Plot"}},"id":"c054a7ac-2ea3-42de-950b-4c1a6c4c99ad","type":"WheelZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"1bd9952c-0339-4639-bba1-da297bae58f0","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"23ba4b25-1cba-4100-8b68-3f73c87bf029","subtype":"Figure","type":"Plot"}},"id":"259a318c-dcf5-4baf-9173-2c0b6eacd01e","type":"PanTool"},{"attributes":{"line_alpha":{"value":0.1},"line_cap":"round","line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"07768890-a9fc-44f0-841a-75cd8a3ba870","type":"Line"},{"attributes":{"axis_label":"Year","formatter":{"id":"0bdbaa63-3d7d-4895-8257-1a52320e5c87","type":"BasicTickFormatter"},"plot":{"id":"23ba4b25-1cba-4100-8b68-3f73c87bf029","subtype":"Figure","type":"Plot"},"ticker":{"id":"d5b60b78-469c-404f-a706-ddadf1d4b0a5","type":"BasicTicker"}},"id":"16d3ce2b-81ee-440c-ab1a-6097271074be","type":"LinearAxis"},{"attributes":{"line_cap":"round","line_color":{"value":"#fee08b"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"be899483-eff1-4e77-ba94-de1d76729f10","type":"Line"},{"attributes":{"bottom":{"field":"bottom"},"fill_alpha":{"value":0.3},"fill_color":{"value":"#B3DE69"},"left":{"field":"left"},"line_alpha":{"value":0.3},"line_color":{"value":"#B3DE69"},"right":{"field":"right"},"top":{"field":"top"}},"id":"3c476bdb-861c-4828-b411-8446bc303a82","type":"Quad"},{"attributes":{"bottom":{"field":"bottom"},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"a89c4ced-e84b-40c9-b315-dc977c274679","type":"Quad"},{"attributes":{},"id":"352d4d0c-e993-46d3-a5e5-086525b42d49","type":"BasicTickFormatter"},{"attributes":{"legends":[["Mia",[{"id":"d8ecaa3a-56b1-4ac5-ba88-e05a10fe679f","type":"GlyphRenderer"}]],["Active Career",[{"id":"ec350945-e9e3-4997-9174-2454a1db3d7c","type":"GlyphRenderer"}]]],"plot":{"id":"23ba4b25-1cba-4100-8b68-3f73c87bf029","subtype":"Figure","type":"Plot"}},"id":"73cc5fc6-bdfb-4a99-9a52-6b7ac1c19d27","type":"Legend"},{"attributes":{"plot":{"id":"23ba4b25-1cba-4100-8b68-3f73c87bf029","subtype":"Figure","type":"Plot"}},"id":"7f0e5b73-afcb-4bd0-aa41-ccab5c33030e","type":"SaveTool"},{"attributes":{"data_source":{"id":"624a9f5e-dff4-4704-bc8e-d1ff11a440f3","type":"ColumnDataSource"},"glyph":{"id":"be899483-eff1-4e77-ba94-de1d76729f10","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"07768890-a9fc-44f0-841a-75cd8a3ba870","type":"Line"},"selection_glyph":null},"id":"d8ecaa3a-56b1-4ac5-ba88-e05a10fe679f","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"23ba4b25-1cba-4100-8b68-3f73c87bf029","subtype":"Figure","type":"Plot"}},"id":"1a3a20d3-dd68-4e9c-8bc1-52f8908ef70d","type":"ResetTool"},{"attributes":{"dimension":1,"plot":{"id":"23ba4b25-1cba-4100-8b68-3f73c87bf029","subtype":"Figure","type":"Plot"},"ticker":{"id":"4c79a0bb-2409-4bd7-b7c8-b7634065e956","type":"BasicTicker"}},"id":"56aec08e-b0a6-4fef-b824-5fc0969e85fc","type":"Grid"},{"attributes":{"below":[{"id":"16d3ce2b-81ee-440c-ab1a-6097271074be","type":"LinearAxis"}],"left":[{"id":"96476bfb-9aef-45ef-b6e9-d280f00e3f7a","type":"LinearAxis"}],"renderers":[{"id":"16d3ce2b-81ee-440c-ab1a-6097271074be ...
# Here's how Mia Hamm influenced for the name Mia:
# 779 babies named Mia were born in 1991, Mia Hamm's rookie year.
# 7394 babies named Mia were born in 2004, Mia Hamm's last active year.
# On average, 2656.85 babies named Mia were born while athlete's career was active.
# Comparatively, babies named Mia averaged 539.0 in the preceeding generation (25 years).
# The frequency of babies named Mia changed by 392.92% after the athlete's rookie debut.
# Mia Hamm probablly inspired the names of 19716 babies.
#     <div class="bk-root">
#         <div class="plotdiv" id
type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"99604295-99ea-4e51-a498-02caef158dc8","type":"BoxAnnotation"},{"attributes":{"dimension":1,"plot":{"id":"d5d9fe53-0ea1-4d25-a644-affc393d2707","subtype":"Figure","type":"Plot"},"ticker":{"id":"82da6afe-231d-4e36-b1be-46ae7321fbb2","type":"BasicTicker"}},"id":"caddbe49-b566-4f2f-ba4c-8fba564b0540","type":"Grid"},{"attributes":{"plot":{"id":"d5d9fe53-0ea1-4d25-a644-affc393d2707","subtype":"Figure","type":"Plot"},"ticker":{"id":"6f86a106-31b3-4482-af43-9eb75550ecd1","type":"BasicTicker"}},"id":"594ff0f2-fe1a-43d4-958b-ec28b73a41fe","type":"Grid"},{"attributes":{"callback":null},"id": ...
# Here's how Tiger Woods influenced for the name Tiger:
# 18 babies named Tiger were born in 1996, Tiger Woods's rookie year.
# 33 babies named Tiger were born in 2014, Tiger Woods's last active year.
# On average, 44.06 babies named Tiger were born while athlete's career was active.
# Comparatively, babies named Tiger averaged 7.29 in the preceeding generation (25 years).
# The frequency of babies named Tiger changed by 504.39% after the athlete's rookie debut.
# Tiger Woods probablly inspired the names of 736 babies.
#     <div class="bk-root">
#         <div class="plotdiv" id="c6b974e9-e75b-473e-b218-e8dc60174ee7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
# ...
# Here's how Serena Williams influenced for the name Serena:
# 830 babies named Serena were born in 1995, Serena Williams's rookie year.
# 696 babies named Serena were born in 2014, Serena Williams's last active year.
# On average, 1012.32 babies named Serena were born while athlete's career was active.
# Comparatively, babies named Serena averaged 509.64 in the preceeding generation (25 years).
# The frequency of babies named Serena changed by 98.63% after the athlete's rookie debut.
# Serena Williams probablly inspired the names of 5218 babies.
#     <div class="bk-root">
#         <div class="plotdiv" id="1ae9e861-0b98-4761-9013-1dc093a22375"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1ae9e861-0b98-4761-9013-1dc093a22375");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1ae9e861-0b98-4761-9013-1dc093a22375' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"04ee3c9b-a1e0-4ed9-a65a-5a685bf023bd":{"roots":{"references":[{"attributes":{},"id":"33f54682-6808-4328-a37f-3fa3c5935a19","type":"ToolEvents"},{"attributes":{"overlay":{"id":"bcfb5649-2594-4899-aee4-8c96d0e475b1","type":"BoxAnnotation"},"plot":{"id":"4e73f6de-b31a-4f1f-bc7e-859dffcb6513","subtype":"Figure","type":"Plot"}},"id":"f4ff4642-1846-4f0d-b63e-bd03a5b4f7f6","type":"BoxZoomTool"},{"attributes":{"line_cap":"round","line_color":{"value":"#d53e4f"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"7c3ed6ae-2b55-4baa-af89-20f2b2f3e525","type":"Line"},{"attributes":{"bottom":{"field":"bottom"},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"66924520-ec06-4dd8-ba0c-5084b6dd9dff","type":"Quad"},{"attributes":{"data_source":{"id":"6063f9c5-d471-453e-aeba-256365664fdd","type":"ColumnDataSource"},"glyph":{"id":"da02d64e-3eb2-4c7a-8f36-eaa13b72a475","type":"Quad"},"hover_glyph":null,"nonselection_glyph":{"id":"66924520-ec06-4dd8-ba0c-5084b6dd9dff","type":"Quad"},"selection_glyph":null},"id":"07c792c6-1975-4b60-a7d7-8260f5d00528","type":"GlyphRenderer"},{"attributes":{"axis_label":"Year","formatter":{"id":"61992c63-f340-4e8b-b52a-caf8c8468a55","type":"BasicTickFormatter"},"plot":{"id":"4e73f6de-b31a-4f1f-bc7e-859dffcb6513","subtype":"Figure","type":"Plot"},"ticker":{"id":"f51d8672-050a-49a8-9cb3-656361e48f3c","type":"BasicTicker"}},"id":"f998873b-b086-48a0-b319-432d48fb537c","type":"LinearAxis"},{"attributes":{"legends":[["Kobe",[{"id":"87290de9-62c4-4dd7-97fe-d9224662e98d","type":"GlyphRenderer"}]],["Active Career",[{"id":"07c792c6-1975-4b60-a7d7-8260f5d00528","type":"GlyphRenderer"}]]],"plot":{"id":"4e73f6de-b31a-4f1f-bc7e-859dffcb6513","subtype":"Figure","type":"Plot"}},"id":"0b529ca6-1ed7-491f-9956-6f50d1cdd3a8","type":"Legend"},{"attributes":{"plot":{"id":"4e73f6de-b31a-4f1f-bc7e-859dffcb6513","subtype":"Figure","type":"Plot"}},"id":"4ce94af3-9d47-4d49-bc5a-b3c7f1782bb2","type":"SaveTool"},{"attributes":{"plot":{"id":"4e73f6de-b31a-4f1f-bc7e-859dffcb6513","subtype":"Figure","type":"Plot"}},"id":"297adbfc-9d01-44f2-888f-8acb873f6799","type":"HelpTool"},{"attributes":{"plot":{"id":"4e73f6de-b31a-4f1f-bc7e-859dffcb6513","subtype":"Figure","type":"Plot"}},"id":"c5e4609a-c21b-4919-acd1-57b436fd310f","type":"ResetTool"},{"attributes":{},"id":"0fbeffd3-974d-43ba-8de5-915770523321","type":"BasicTicker"},{"attributes":{},"id":"f51d8672-050a-49a8-9cb3-656361e48f3c","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"4e73f6de-b31a-4f1f-bc7e-859dffcb6513","subtype":"Figure","type":"Plot"},"ticker":{"id":"0fbeffd3-974d-43ba-8de5-915770523321","type":"BasicTicker"}},"id":"b368ab43-801c-4781-80a3-8fda21ac1d86","type":"Grid"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1989,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014],"y":[5,9,87,350,1104,860,1432,1552,1392,1212,625,443,468,572,730,685,643,553,522,549,512]}},"id":"dcef085c-ea72-49d0-9f38-ca7f530f0385","type":"ColumnDataSource"},{"attributes":{"axis_label":"Count","formatter":{"id":"bf713144-c2d1-4eac-b209-e3ab85697acb","type":"BasicTickFormatter"},"plot":{"id":"4e73f6de-b31a-4f1f-bc7e-859dffcb6513","subtype":"Figure","type":"Plot"},"ticker":{"id":"0fbeffd3-974d-43ba-8de5-915770523321","type":"BasicTicker"}},"id":"3bb285a0-ca7e-413b-a7cd-43b687c424b1","type":"LinearAxis"},{"attributes":{"plot":{"id":"4e73f6de-b31a-4f1f-bc7e-859dffcb6513","subtype":"Figure","type":"Plot"}},"id":"2d47b73f-594d-4eee-acb2-8ef4447d7df3","type":"WheelZoomTool"},{"attributes":{"callback":null},"id":"509c28f4-eb2c-4a9e-805e-55aae3296d03","type":"DataRange1d"},{"attributes":{"bottom":{"field":"bottom"},"fill_alpha":{"value":0.3},"fill_color":{"value":"#B3DE69"},"left":{"field":"left"},"line_alpha":{"value":0.3},"line_color":{"valu ...
# Here's how Kobe Bryant influenced for the name Kobe:
# 87 babies named Kobe were born in 1996, Kobe Bryant's rookie year.
# 512 babies named Kobe were born in 2014, Kobe Bryant's last active year.
# On average, 765.5 babies named Kobe were born while athlete's career was active.
# Comparatively, babies named Kobe averaged 7.0 in the preceeding generation (25 years).
# The frequency of babies named Kobe changed by 10835.71% after the athlete's rookie debut.
# Kobe Bryant probablly inspired the names of 13763 babies.
#     <div class="bk-root">
#         <div class="plotdiv" id="e2b8520e-3b03-4a66-b974-c3da99e86b2f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e2b8520e-3b03-4a66-b974-c3da99e86b2f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e2b8520e-3b03-4a66-b974-c3da99e86b2f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"c933ef92-a140-4be2-ae6b-747a51e0f766":{"roots":{"references":[{"attributes":{"plot":null,"text":"Lebron James Inspired Trends: Lebron"},"id":"6d86b798-4239-4971-b854-0e2f5ebdbc44","type":"Title"},{"attributes":{"legends":[["Lebron",[{"id":"422b52da-72e4-4d8f-bf44-126ae2483b35","type":"GlyphRenderer"}]],["Active Career",[{"id":"c5cb43d1-e113-47d3-b78c-37874dc9399c","type":"GlyphRenderer"}]]],"plot":{"id":"78eb6da2-e3de-499f-bf0c-c466285fe8a7","subtype":"Figure","type":"Plot"}},"id":"00ae655b-22f1-4129-a90f-e1b4545fd86a","type":"Legend"},{"attributes":{"plot":{"id":"78eb6da2-e3de-499f-bf0c-c466285fe8a7","subtype":"Figure","type":"Plot"}},"id":"1a39e301-bc73-4f65-bde0-3107238b8bba","type":"WheelZoomTool"},{"attributes":{"axis_label":"Year","formatter":{"id":"4267d972-88e3-4db8-88ee-fa4c1e2983d4","type":"BasicTickFormatter"},"plot":{"id":"78eb6da2-e3de-499f-bf0c-c466285fe8a7","subtype":"Figure","type":"Plot"},"ticker":{"id":"6a0683f1-1273-46fc-8873-2af88c5d69fb","type":"BasicTicker"}},"id":"bfd64eec-26a9-4f5e-badd-ca25f9e6be0d","type":"LinearAxis"},{"attributes":{},"id":"1791109e-5e82-4050-9ebf-97c8098ff9cf","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"78eb6da2-e3de-499f-bf0c-c466285fe8a7","subtype":"Figure","type":"Plot"}},"id":"fbc521c2-4d05-42cc-ad77-1177bc1ee947","type":"PanTool"},{"attributes":{"callback":null,"column_names":["left","right","bottom","top"],"data":{"bottom":[0],"left":[2003],"right":[2014],"top":[110]}},"id":"c282f15e-9667-484e-b1aa-24a7f0a8c0e2","type":"ColumnDataSource"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"dc2e1725-b0be-4d9d-a745-2f994d3647fa","type":"BoxAnnotation"},{"attributes":{"dimension":1,"plot":{"id":"78eb6da2-e3de-499f-bf0c-c466285fe8a7","subtype":"Figure","type":"Plot"},"ticker":{"id":"f138e3b6-be04-4b01-bc6f-7e2c21cff003","type":"BasicTicker"}},"id":"cfa1103b-983f-46f9-a06d-e1cc9ebe412f","type":"Grid"},{"attributes":{"plot":{"id":"78eb6da2-e3de-499f-bf0c-c466285fe8a7","subtype":"Figure","type":"Plot"}},"id":"cacc3a62-db13-4d2c-bfc2-b6264c8d346c","type":"HelpTool"},{"attributes":{},"id":"4baf6493-0cd2-426f-b3e1-d5206045db27","type":"ToolEvents"},{"attributes":{"overlay":{"id":"dc2e1725-b0be-4d9d-a745-2f994d3647fa","type":"BoxAnnotation"},"plot":{"id":"78eb6da2-e3de-499f-bf0c-c466285fe8a7","subtype":"Figure","type":"Plot"}},"id":"5fb83ab3-e90f-4d95-97d2-f5008e143e8e","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"78eb6da2-e3de-499f-bf0c-c466285fe8a7","subtype":"Figure","type":"Plot"},"ticker":{"id":"6a0683f1-1273-46fc-8873-2af88c5d69fb","type":"BasicTicker"}},"id":"b08566a6-f29f-47f6-a2c2-ba5d8a05537e","type":"Grid"},{"attributes":{},"id":"6a0683f1-1273-46fc-8873-2af88c5d69fb","type":"BasicTicker"},{"attributes":{},"id":"f138e3b6-be04-4b01-bc6f-7e2c21cff003","type":"BasicTicker"},{"attributes":{"bottom":{"field":"bottom"},"fill_alpha":{"value":0.3},"fill_color":{"value":"#B3DE69"},"left":{"field":"left"},"line_alpha":{"value":0.3},"line_color":{"value":"#B3DE69"},"right":{"field":"right"},"top":{"field":"top"}},"id":"e37980c1-38c6-4c7c-b373-cd5cc1944f1a","type":"Quad"},{"attributes":{"line_alpha":{"value":0.1},"line_cap":"round","line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"c0324f65-7f2e-4799-8003-8b282c3f2d55","type":"Line"},{"attributes":{"data_source":{"id":"c282f15e-9667-484e-b1aa-24a7f0a8c0e2","type":"ColumnDataSource"},"glyph":{"id":"e37980c1-38c6-4c7c-b373-cd5cc1944f1a","type":"Quad"},"hover_glyph":null,"nonselection_glyph":{"id":"d603c12b-148c-4cb8-a842-06449f02b6c0","type":"Quad"},"selection_glyph":null},"id":"c5cb43d1-e113-47d3-b78c-37874dc9399c","type":"GlyphRenderer"},{"attributes":{},"id":"4267d972-88e3 ...
# Here's how Lebron James influenced for the name Lebron:
# 42 babies named Lebron were born in 2003, Lebron James's rookie year.
# 39 babies named Lebron were born in 2014, Lebron James's last active year.
# On average, 80.45 babies named Lebron were born while athlete's career was active.
# Comparatively, babies named Lebron averaged 6.36 in the preceeding generation (25 years).
# The frequency of babies named Lebron changed by 1164.94% after the athlete's rookie debut.
# Lebron James probablly inspired the names of 787 babies.
